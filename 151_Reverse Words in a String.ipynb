# %%
def reverseWords(s):
    """
    :type s: str
    :rtype: str
    """
    s_list = s.split (" ")
    s_list = list(filter(None, s_list))
    r_str = ""

    for r in s_list[::-1]:
        r_str += r + " "
    return r_str [0:len(r_str)-1]

s = "The sky is blue."
reverseW=reverseWords (s)
reverseW
# Out:
# 'blue. is sky The'
